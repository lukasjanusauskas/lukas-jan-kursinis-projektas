# %%
import pandas as pd

# %%
df_qrf = pd.read_csv('../results.csv')
df_lstm = pd.read_csv('../results-lstm.csv')

# %%
(
    df_qrf['picp_delta_cog'].min(),
    df_qrf['picp_delta_cog'].max()
)
# Out:
# (np.float64(0.9363882878535514), np.float64(0.9388960493135332))

# %%
(
    df_lstm['picp_delta_cog'].min(),
    df_lstm['picp_delta_cog'].max()
)
# Out:
# (np.float64(0.949571768808082), np.float64(0.9587752369981788))

# %%
(
    df_qrf['picp_delta_dif'].min(),
    df_qrf['picp_delta_dif'].max()
)
# Out:
# (np.float64(0.9331075170062731), np.float64(0.9353314031319074))

# %%
(
    df_lstm['picp_delta_dif'].min(),
    df_lstm['picp_delta_dif'].max()
)
# Out:
# (np.float64(0.94997960803848), np.float64(0.9568718283988668))

# %%
(
    df_qrf['pinaw_delta_cog'].min(),
    df_qrf['pinaw_delta_cog'].max()
)
# Out:
# (np.float64(0.2669197128708245), np.float64(0.27039009125213))

# %%
(
    df_lstm['pinaw_delta_cog'].min(),
    df_lstm['pinaw_delta_cog'].max()
)
# Out:
# (np.float64(0.27181694), np.float64(0.2899082))

# %%
(
    df_qrf['pinaw_delta_dif'].min(),
    df_qrf['pinaw_delta_dif'].max()
)
# Out:
# (np.float64(0.1368880671299836), np.float64(0.138216127014242))

# %%
(
    df_lstm['pinaw_delta_dif'].min(),
    df_lstm['pinaw_delta_dif'].max()
)
# Out:
# (np.float64(0.14364047), np.float64(0.14811933))
