# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras_tuner
# Out:
# 2026-09-03 23:16:20.438293: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-03 23:16:20.462924: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-09-03 23:16:20.629742: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-09-03 23:16:20.631090: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import sys
sys.path.append('..')
from src.lstm_ae_funkcijos import lstm_ae_hp
from keras_tuner import GridSearch

# %%
gs_low = GridSearch(
    hypermodel = lambda hp: lstm_ae_hp(
        tau=0.975,
        hp=hp,
        n_out_features=3,
        n_out_timesteps=25
    ),
    objective = 'val_loss',
    directory='../lstm-ae-07-26-2',
    project_name='lstm-ae-low'
)

gs_low.get_best_hyperparameters()[0].values
# Out:
# Reloading Tuner from ../lstm-ae-07-26-2/lstm-ae-low/tuner0.json
# {'latent_dim': 5, 'lstm_dim': 10, 'drop_frac': 0.05, 'l1': 0.01}

# %%
gs_high = GridSearch(
    hypermodel = lambda hp: lstm_ae_hp(
        tau=0.975,
        hp=hp,
        n_out_features=3,
        n_out_timesteps=25
    ),
    objective = 'val_loss',
    directory='../lstm-ae-07-26-2',
    project_name='lstm-ae-high'
)

gs_high.get_best_hyperparameters()[0].values
# Out:
# Reloading Tuner from ../lstm-ae-07-26-2/lstm-ae-high/tuner0.json
# {'latent_dim': 5, 'lstm_dim': 10, 'drop_frac': 0.05, 'l1': 0.01}
