# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

plt.style.use('bmh')
plt.rcParams['axes.facecolor'] = 'white'
BATCH_SIZE = 128
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779994903.446733   64655 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1779994903.826184   64655 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779994905.395347   64655 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
y = np.load('../anom-y.npy')

# %%
y.shape[0]
# Out:
# 1364

# %%
y.shape
# Out:
# (1364, 25, 2)

# %%
from datetime import datetime
timestamps = list(pd.date_range(start=datetime(2024,11,18,0,0), end=datetime(2024,11,19,0,0), freq='60s')[51:-26])

# %%
y_anom_low = np.load('../y_low_anom.npy')
y_anom_high = np.load('../y_high_anom.npy')

y_flat = y[:, 0, 0].ravel()
y_high = y_anom_high[:, 0].ravel()
y_low = y_anom_low[:, 0].ravel()

anomalies_x = []
anomalies_y = []
for i in range(y.shape[0]):

    if y_flat[i] < y_low[i]:
        anomalies_x.append( timestamps[i] )
        anomalies_y.append( y_flat[i] )

    elif y_flat[i] > y_high[i]:
        anomalies_x.append( timestamps[i] )
        anomalies_y.append( y_flat[i] )

plt.plot(timestamps, y[:, 0, 0].ravel(), label = "Tikroji reikšmė", color='black', alpha=0.6)
plt.plot(timestamps, y_anom_high[:, 0].ravel(), color='#185288', linestyle='--', linewidth=2)
plt.plot(timestamps, y_anom_low[:, 0].ravel(), color="#185288", linestyle='--')

plt.xticks(
    ticks=[datetime(2024,11,18, 3+x*6,0) for x in range(0, 4)],
    labels=[f"2024-11-18\n{(3+x*6):02}:00" for x in range(0, 4)],
)
plt.tick_params(axis='both', which='both', labelsize=13)

plt.xlabel('Laiko žyma (UTC)', size=18)
plt.ylabel('COG minutinis pokytis', size=18)
plt.title('Yi-Peng 3 COG minutinio pokyčio\nLSTM-AE prognozės intervalas', size=20)

plt.fill_between(timestamps, y1=y_anom_low[:, 0].ravel(), y2=y_anom_high[:, 0].ravel(), alpha=0.4, label='Prognozės intervalas')
plt.scatter(anomalies_x, anomalies_y, color='red', s=20, zorder=5, label='Į PI nepatenkantys\nstebėjimai')
plt.legend(fontsize=13)

plt.tight_layout()
# plt.savefig("cog-difference-res-lstm-ae.png", dpi=750)

plt.show()

# %%
should_capture = np.array(timestamps) > datetime(2024,11,18,8,30)

y_flat = y[should_capture, 0, 0].ravel()
y_high = y_anom_high[should_capture, 0].ravel()
y_low = y_anom_low[should_capture, 0].ravel()

np.mean( (y_flat < y_high) & (y_flat > y_low) )
# Out:
# np.float64(0.7400442477876106)

# %%
from scipy.stats import binom
confidence=0.9
n=y_flat.shape[0]
p=0.918
binom.interval(confidence, n, p)[0]/n
# Out:
# np.float64(0.9026548672566371)

# %%
should_capture = np.array(timestamps) > datetime(2024,11,18,10,30)

y_flat = y[should_capture, 0, 1].ravel()
y_high = y_anom_high[should_capture, 1].ravel()
y_low = y_anom_low[should_capture, 1].ravel()

np.mean( (y_flat < y_high) & (y_flat > y_low) )
# Out:
# 0.9987244897959183

# %%
from scipy.stats import binom
confidence=0.99
n=y_flat.shape[0]
p=0.956
binom.interval(confidence, n, p)[0]/n
# Out:
# np.float64(0.9380530973451328)

# %%
y_anom_low = np.load('../y_low_anom.npy')
y_anom_high = np.load('../y_high_anom.npy')

y_flat = y[:, 0, 1].ravel()
y_high = y_anom_high[:, 1].ravel()
y_low = y_anom_low[:, 1].ravel()

anomalies_x = []
anomalies_y = []
for i in range(y.shape[0]):

    if y_flat[i] < y_low[i]:
        anomalies_x.append( timestamps[i] )
        anomalies_y.append( y_flat[i] )

    elif y_flat[i] > y_high[i]:
        anomalies_x.append( timestamps[i] )
        anomalies_y.append( y_flat[i] )

plt.plot(timestamps, y[:, 0, 1].ravel(), label = "Tikroji reikšmė", color='black', alpha=0.6)
plt.plot(timestamps, y_anom_high[:, 1].ravel(), color='#185288', linestyle='--', linewidth=2)
plt.plot(timestamps, y_anom_low[:, 1].ravel(), color="#185288", linestyle='--')

plt.xticks(
    ticks=[datetime(2024,11,18, 3+x*6,0) for x in range(0, 4)],
    labels=[f"2024-11-18\n{(3+x*6):02}:00" for x in range(0, 4)],
)
plt.tick_params(axis='both', which='both', labelsize=13)

plt.xlabel('Laiko žyma (UTC)', size=18)
plt.ylabel('$dif$ minutinis pokytis', size=18)
plt.title('Yi-Peng 3 $dif$ minutinio pokyčio\nLSTM-AE prognozės intervalas', size=20)

plt.fill_between(timestamps, y1=y_anom_low[:, 0].ravel(), y2=y_anom_high[:, 0].ravel(), alpha=0.4, label='Prognozės intervalas')
plt.scatter(anomalies_x, anomalies_y, color='red', s=20, zorder=5, label='Į PI nepatenkantys\nstebėjimai')
plt.legend(fontsize=13)

plt.tight_layout()
plt.savefig("dif-difference-res-lstm-ae.png", dpi=750)

plt.show()

# %%
y[:, 0, 0].ravel().shape
# Out:
# (1364,)

# %%
y_anom_high[:, 0].ravel().shape
# Out:
# (1364,)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.patches import ConnectionPatch

picps = np.load('../output/picp-through-time.npy')

fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(range(1, 26), picps[:, 0], label='COG minutinis\npokytis')
ax.scatter(range(1, 26), picps[:, 1], label='$dif$ minutinis\npokytis')
ax.set_ylim((0, 1.05))
ax.set_xlim((0, 26))

# Rectangle border around the region of interest
rect = mpatches.Rectangle(
    (0.5, 0.905),
    25.0,
    0.05,
    linewidth=1.5,
    edgecolor='#71797E',
    facecolor='none',
    zorder=5
)
ax.add_patch(rect)

# ── Inset axes ────────────────────────────────────────────────────────────────
axins = ax.inset_axes([0.08, 0.28, 0.55, 0.35])
axins.scatter(range(1, 26), picps[:, 0])
axins.scatter(range(1, 26), picps[:, 1])
axins.set_xlim(0.5, 25.5)
axins.set_ylim(0.905, 0.955)
axins.set_xlabel('', fontsize=12)
axins.tick_params(labelsize=12)          # was 7
axins.set_facecolor('white')
for spine in axins.spines.values():
    spine.set_edgecolor('#71797E')
    spine.set_linewidth(1.5)

# ── Connection lines ──────────────────────────────────────────────────────────
con_left = ConnectionPatch(
    xyA=(0.5, 0.91), coordsA=ax.transData,
    xyB=(0, 0.935),      coordsB=axins.transAxes,
    color='#71797E', linewidth=1.2, linestyle='--'
)
con_right = ConnectionPatch(
    xyA=(25.5, 0.91), coordsA=ax.transData,
    xyB=(1, 0.97),        coordsB=axins.transAxes,
    color='#71797E', linewidth=1.2, linestyle='--'
)
fig.add_artist(con_left)
fig.add_artist(con_right)

ax.legend(loc='lower right', fontsize=16)          # added fontsize
ax.set_xlabel('Laiko žingsnis', fontsize=18)        # added fontsize
ax.set_ylabel('PICP', fontsize=18)                  # added fontsize
ax.set_title('PICP laike', fontsize=24)             # added fontsize
ax.tick_params(labelsize=16)                        # added for axis tick labels

plt.tight_layout()
plt.savefig('picp_with_inset.png', dpi=750)
plt.show()

# %%
pinaws = np.load('../output/pinaw-through-time.npy')

fig, ax = plt.subplots(figsize=(10, 6))

plt.scatter(range(1, 26), pinaws[:, 0], label='COG minutinis\npokytis')
plt.scatter(range(1, 26), pinaws[:, 1], label='$dif$ minutinis\npokytis')

plt.title('PINAW laike', size=24)
plt.xlabel('Laiko žingsnis', fontdict={'size':18})
plt.ylabel('PINAW', fontdict={'size':18})
plt.tick_params(axis='both', labelsize=14)

plt.legend(loc='center right', fontsize=14)


plt.tight_layout()
plt.savefig('pinaw_lstm_ae.png', dpi=750)
plt.show()

# %%
X_train = np.load('../X_train_COGoutput.npy')
y_train = np.load('../y_train_COGoutput.npy')
X_val = np.load('../X_val_COGoutput.npy')
y_val = np.load('../y_val_COGoutput.npy')
X_test = np.load('../X_test_COGoutput.npy')
y_test = np.load('../y_test_COGoutput.npy')

# https://www.tensorflow.org/tutorials/load_data/numpy:
train_dataset = tf.data\
    .Dataset\
    .from_tensor_slices(
        (X_train, y_train)
    )\
    .batch(BATCH_SIZE)\
    .shuffle(buffer_size=10_000)

val_dataset = tf.data\
    .Dataset\
    .from_tensor_slices(
        (X_val, y_val)
    )\
    .batch(BATCH_SIZE)\
    .shuffle(buffer_size=10_000)

test_dataset = tf.data\
    .Dataset\
    .from_tensor_slices(
        (X_test, y_test)
    )\
    .batch(BATCH_SIZE)\
    .shuffle(buffer_size=10_000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 X_train = np.load('../X_train_COGoutput.npy')
#       2 y_train = np.load('../y_train_COGoutput.npy')
#       3 X_val = np.load('../X_val_COGoutput.npy')
#
# File ~/Dokumentai/studijos/kursinis-projektas/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../X_train_COGoutput.npy'

# %%
import pickle

# %%
import tensorflow as tf
import sys
sys.path.append('..')
from src.lstm_ae_funkcijos import LSTM_AE, quantile_loss

# %%
model_low = LSTM_AE(
    latent_dim=5,
    lstm_units=10,
    n_out_features=y_train.shape[2],
    n_out_timesteps=y_train.shape[1],
    drop_frac=0.05
)

model_high = LSTM_AE(
    latent_dim=5,
    lstm_units=10,
    n_out_features=y_train.shape[2],
    n_out_timesteps=y_train.shape[1],
    drop_frac=0.05
)

model_low.compile(optimizer='adam', loss=quantile_loss(0.025))
model_high.compile(optimizer='adam', loss=quantile_loss(0.975))

model_low.load_weights('../lstm_ae_first_low.weights.h5')
model_high.load_weights('../lstm_ae_first_high.weights.h5')
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 1 variables whereas the saved optimizer has 18 variables.
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 1 variables whereas the saved optimizer has 18 variables.

# %%
X = np.load('../anom-x.npy')
y = np.load('../anom-y.npy')

# %%
y_high = model_high.predict(X)
y_low = model_low.predict(X)
# Out:
# 43/43 [==============================] - 1s 2ms/step
# 43/43 [==============================] - 1s 2ms/step

# %%
plt.plot( y_low[:, 0].ravel(), label='upper')
plt.plot( y[:, 0].ravel(), label='true')
plt.plot( y_high[:, 0].ravel(), label='lower')
plt.legend()

# %%
timestamps_not_smooth = timestamps[26:-25]
timestamps_smooth = timestamps[50:-25]

# %%
from datetime import datetime

# %%
plt.plot(y_arr_smooth[:, 0])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 y_true
#
# NameError: name 'y_true' is not defined

# %%
def plot_pi(y_true, y_low, y_high, variable_name: str, timestamps: pd.Series):

    anomalies_x = []
    anomalies_y = []
    for i in range(y_true.shape[0]):

        if y_true[i] < y_low[i]:
            anomalies_x.append( timestamps[i] )
            anomalies_y.append( y_true[i] )

        elif y_true[i] > y_high[i]:
            anomalies_x.append( timestamps[i] )
            anomalies_y.append( y_true[i] )

    plt.plot(timestamps, y_low, label='Prognozės\nintervalas', lw=1, linestyle='--', color='#0D77A7')
    plt.plot(timestamps, y_high, lw=1, linestyle='--', color='#0D77A7')
    plt.fill_between(x=timestamps, y1=y_low, y2=y_high, alpha=0.2)
    plt.plot(timestamps, y_true, label='Tikroji\nreikšmė', lw=1.5, color='black')

    plt.scatter(anomalies_x, anomalies_y, color='red', label='Anomalijos')

    plt.ylabel(variable_name, size=20)
    plt.title(f'Laivo Yi-Peng 3\n{variable_name} incidento metu', size=22)

    plt.tick_params(axis='both', labelsize=18)
    plt.xticks(
        ticks=[datetime(2024, 11, 18, 0, 0), datetime(2024, 11, 18, 12, 0), datetime(2024, 11, 19, 0, 0)],
        labels=['2024-11-18\n00:00 UTC', '2024-11-18\n12:00 UTC', '2024-11-19\n00:00 UTC']
    )

    plt.legend()
    plt.tight_layout()
    plt.savefig('delta_dif_old.png', dpi=750)

    plt.show()

plot_pi(
    y_arr_smooth[:, 0, 0],
    y_low_smooth[:, 0, 0],
    y_high_smooth[:, 0, 0],
    r'$\Delta dif^*$',
    timestamps_smooth
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 37
#      33     plt.savefig('delta_dif_old.png', dpi=750)
#      35     plt.show()
# ---> 37 plot_pi(
#      38     y_arr_smooth[:, 0, 0],
#      39     y_low_smooth[:, 0, 0],
#      40     y_high_smooth[:, 0, 0],
#      41     r'$\Delta dif^*$',
#      42     timestamps_smooth
#      43 )
#
# Cell In[18], line 8, in plot_pi(y_true, y_low, y_high, variable_name, timestamps)
#       5 for i in range(y_true.shape[0]):
#       7     if y_true[i] < y_low[i]:
# ----> 8         anomalies_x.append( timestamps[i] )
#       9         anomalies_y.append( y_true[i] )
#      11     elif y_true[i] > y_high[i]:
#
# IndexError: index 1364 is out of bounds for axis 0 with size 1364

# %%
y_low_dif[:, 0].reshape(-1)
# Out:
# array([ 0.00341398,  0.00418879,  0.00472241, ..., -0.00089213,
#        -0.00184586, -0.01054826], dtype=float32)

# %%
y_high_dif.min()
# Out:
# np.float32(-0.600756)

# %%
plot_pi(
    y_arr_smooth[:, 0, 0],
    y_low_dif[:, 1].reshape(-1),
    y_high_dif[:, 1].reshape(-1),
    r'$\Delta dif^*$',
    timestamps_smooth
)

# %%
plot_pi(
    y_arr_smooth[:, 0, 0],
    y_low_dif[:, 1].reshape(-1),
    y_low_dif[:, 1].reshape(-1),
    r'$\Delta dif^*$',
    timestamps_smooth
)

# %%
plot_pi(
    y_arr_not_smooth[:, 0, 0],
    y_low_not_smooth[:, 0, 0],
    y_high_not_smooth[:, 0, 0],
    r'$\Delta dif^*$',
    timestamps_not_smooth
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 plot_pi(
#       2     y_arr_not_smooth[:, 0, 0],
# ----> 3     y_low_not_smooth[:, 0, 0],
#       4     y_high_not_smooth[:, 0, 0],
#       5     r'$\Delta dif^*$',
#       6     timestamps_not_smooth
#       7 )
#
# NameError: name 'y_low_not_smooth' is not defined

# %%
np.mean( quantile_loss(0.025)( y_arr_smooth, y_low_smooth ) )
# Out:
# np.float64(0.029002030274781116)

# %%
plot_pi(
    y_arr_smooth[:, 24, 1],
    y_low_smooth[:, 24, 1],
    y_high_smooth[:, 24, 1],
    r'$dif^*$',
    timestamps_smooth
)

# %%
plot_pi(
    y_arr_not_smooth[:, 0, 1],
    y_low_not_smooth[:, 0, 1],
    y_high_not_smooth[:, 0, 1],
    r'$dif^*$',
    timestamps_not_smooth
)

# %% [markdown]
# - Heading ir COG skiriasi matavimo tikslumas
# - Pabandyti su moving average
# - Pažiūrėti, kiek duomenų interpoliuota, koks pasiskirstymas
#
#
# MMSI: 304473000 (HAV Dolphin), 311014800 (HAV Snapper)
